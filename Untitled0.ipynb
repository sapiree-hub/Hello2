# %% [markdown]
# <a href="https://colab.research.google.com/github/sapiree-hub/Hello2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Ethan Sapire
#*NEUR 265*
#**February 2026**

# %%
#Here I copied the cell from the instructions in order to import pyplot
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
#here I am importing the CSV files as panda dataframes
pandas_data1 = pd.read_csv("https://raw.githubusercontent.com/hallockh/neur_265_spring2026/main/data/v_rest_sst.csv")
pandas_data2 = pd.read_csv("https://raw.githubusercontent.com/hallockh/neur_265_spring2026/main/data/v_rest_pvalb.csv")

# %%
data1 = pandas_data1.values.tolist()
data2 = pandas_data2.values.tolist()
print(data1)
print(data2)
# Out:
# [[-69.60158234], [-76.03420105], [-71.16118393], [-76.35402679], [-70.89105013], [-64.11880341], [-72.8632112], [-78.96890068], [-55.4531032], [-60.98506045], [-66.61118807], [-67.08294233], [-73.90523593], [-74.63317594], [-49.27067811], [-76.05053997], [-65.45417595], [-58.53314018], [-66.28985665], [-64.09106996], [-71.49303228], [-65.11718958], [-73.74140637], [-74.81462097], [-71.32343356], [-74.46990373], [-65.03939126], [-71.94757271], [-73.42034054], [-71.10602856], [-61.28795481], [-73.79654069], [-64.48533249], [-69.65824959], [-73.71225967], [-85.56860669], [-57.49219704], [-76.91730436], [-62.61127641], [-67.08071963], [-78.45983535], [-78.87342682], [-76.14055703], [-62.40101166], [-72.41336346], [-62.03701146], [-63.30990855], [-62.02654052], [-73.0206111], [-63.11713295], [-70.05060087], [-75.7537974], [-57.15310111], [-72.52368011], [-70.86691952], [-65.435009], [-66.87690226], [-70.79107895], [-71.34088898], [-65.70912288], [-64.45794886], [-62.82061958], [-65.033269
# ...

# %%
data1 = np.squeeze(data1)
data2 = np.squeeze(data2)
print(data1)





print(data2)
# Out:
# [-69.60158234 -76.03420105 -71.16118393 -76.35402679 -70.89105013
#  -64.11880341 -72.8632112  -78.96890068 -55.4531032  -60.98506045
#  -66.61118807 -67.08294233 -73.90523593 -74.63317594 -49.27067811
#  -76.05053997 -65.45417595 -58.53314018 -66.28985665 -64.09106996
#  -71.49303228 -65.11718958 -73.74140637 -74.81462097 -71.32343356
#  -74.46990373 -65.03939126 -71.94757271 -73.42034054 -71.10602856
#  -61.28795481 -73.79654069 -64.48533249 -69.65824959 -73.71225967
#  -85.56860669 -57.49219704 -76.91730436 -62.61127641 -67.08071963
#  -78.45983535 -78.87342682 -76.14055703 -62.40101166 -72.41336346
#  -62.03701146 -63.30990855 -62.02654052 -73.0206111  -63.11713295
#  -70.05060087 -75.7537974  -57.15310111 -72.52368011 -70.86691952
#  -65.435009   -66.87690226 -70.79107895 -71.34088898 -65.70912288
#  -64.45794886 -62.82061958 -65.03326961 -61.37704976 -71.51313705
#  -71.54903143 -83.53790652 -68.49228492 -69.6041454  -62.87747123
# ...

# %%
print(len(data1))
# Out:
# 499

# %%
print(data2[2])
print(data2[3])
print(data2[4])
print(data2[5])
# Out:
# -72.36807022
# -63.09300825
# -75.5469301
# -66.51929994

# %%
print(data1[-2])
print(data1[-1])
# Out:
# -65.59535842
# -75.10678711

# %%
print(type(data2))
# Out:
# <class 'numpy.ndarray'>

# %%
plt.hist(data1)
plt.show()

# %%
plt.hist(data1)
plt.xlabel("Resting membrane potential (mV)")
plt.ylabel("Number of cells")
plt.show()

# %%
plt.hist(data2)
plt.show()

# %%
plt.hist(data2)
plt.xlabel("Resting membrane potential (mV)")
plt.ylabel("Number of cells")
plt.show()

# %%
#Between Data 1 and Data2, it appears that the cells in data2 have a more negative resting membrane potenetial

# %%
data3 = [data1, data2]
print(data3)
# Out:
# [array([-69.60158234, -76.03420105, -71.16118393, -76.35402679,
#        -70.89105013, -64.11880341, -72.8632112 , -78.96890068,
#        -55.4531032 , -60.98506045, -66.61118807, -67.08294233,
#        -73.90523593, -74.63317594, -49.27067811, -76.05053997,
#        -65.45417595, -58.53314018, -66.28985665, -64.09106996,
#        -71.49303228, -65.11718958, -73.74140637, -74.81462097,
#        -71.32343356, -74.46990373, -65.03939126, -71.94757271,
#        -73.42034054, -71.10602856, -61.28795481, -73.79654069,
#        -64.48533249, -69.65824959, -73.71225967, -85.56860669,
#        -57.49219704, -76.91730436, -62.61127641, -67.08071963,
#        -78.45983535, -78.87342682, -76.14055703, -62.40101166,
#        -72.41336346, -62.03701146, -63.30990855, -62.02654052,
#        -73.0206111 , -63.11713295, -70.05060087, -75.7537974 ,
#        -57.15310111, -72.52368011, -70.86691952, -65.435009  ,
#        -66.87690226, -70.79107895, -71.34088898, -65.70912288,
# ...

# %%
print(data3[1][-1])
# Out:
# -54.08427915
